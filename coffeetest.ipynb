# %% [markdown]
# <a href="https://colab.research.google.com/github/CincodeCuatro/ML/blob/main/coffeetest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We want to optimize the pastry inventory. Therefore we want to:
# - know what amount of pastry is needed/consumed on a given day
# - how what are possible outliers (and their possible explanations) (e.g., a lot of pastry consumption on casual Friday?)
# - the provided data, as visible, is a time-series of one month (april 2019)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn.metrics import mean_squared_error, r2_score
import io

from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f44c47f9-9714-4ad0-bff3-4d7a9617615c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f44c47f9-9714-4ad0-bff3-4d7a9617615c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pastry_inventory.csv to pastry_inventory.csv

# %%
pastry_inv = pd.read_csv(io.StringIO(uploaded['pastry_inventory.csv'].decode('utf-8')))
# Create a copy of the DataFrame to work from
# Omit random state to have different random split each run #?

pastry_inv_copy = pastry_inv.copy()
train_set = pastry_inv_copy.sample(frac=0.75, random_state=0)
test_set = pastry_inv_copy.drop(train_set.index)

print ('Training set')
print (train_set)
print ('\nTest set')
print (test_set)
print ('\nOriginal DataFrame')
print (pastry_inv_copy)
# Out:
# Training set
#      sales_outlet_id transaction_date  product_id  ...  quantity_sold  waste  % waste
# 63                 3        4/14/2019          71  ...              8     10      56%
# 247                8        4/16/2019          69  ...              9      9      50%
# 296                8        4/25/2019          73  ...             10      8      44%
# 124                5        4/12/2019          71  ...             13      5      28%
# 188                5        4/25/2019          70  ...              5     13      72%
# ..               ...              ...         ...  ...            ...    ...      ...
# 23                 3         4/6/2019          71  ...             13      5      28%
# 186                5        4/24/2019          73  ...              7     11      61%
# 227                8        4/12/2019          69  ...             11      7      39%
# 148                5        4/17/2019          70  ...              6     12      67%
# ...

# %%
#want to show only product 73
product73 = pastry_inv_copy.loc[pastry_inv_copy['product_id'] == 73]
product73
# Out:
#      sales_outlet_id transaction_date  product_id  ...  quantity_sold  waste  % waste
# 4                  3         4/1/2019          73  ...              9      9      50%
# 9                  3         4/2/2019          73  ...              9      9      50%
# 14                 3         4/3/2019          73  ...             15      3      17%
# 19                 3         4/4/2019          73  ...              9      9      50%
# 25                 3         4/6/2019          73  ...              9      9      50%
# 30                 3         4/7/2019          73  ...              3     15      83%
# 35                 3         4/8/2019          73  ...              6     12      67%
# 44                 3        4/10/2019          73  ...              6     12      67%
# 49                 3        4/11/2019          73  ...              3     15      83%
# 54                 3        4/12/2019          73  ...              6     12      67%
# ...
